# %%
def febonacci(n):
    
    a = 0
    b = 1
    
    if n <= 0 :
        return
    elif n == 1 :
        print (a)
        return
    
    print (a, b, end=" ")
    
    for i in range (n - 2):
        
        sum = a + b
        a = b
        b = sum 
        
        print (b, end=" ")

# %%
n = int(input("Enter how much need"))
print (f"user need {n} number of febonacci series")
febonacci(n)
# Out:
# user need 6 number of febonacci series
# 0 1 1 2 3 5
