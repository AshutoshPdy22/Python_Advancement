# %% [markdown]
# <a href="https://colab.research.google.com/github/AshutoshPdy22/Python_Advancement/blob/main/03_ML/AL%2BML%2BNN_Theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Science is a field that attempts to find pattern and draw insight from data (might use ml).
#
# AI + NN + Data Science field at some point overlap into ML

# %% [markdown]
# Type of ML :-
#
#
# *   Supervised learning - uses labeled inputs (means input has a corresponding output label) to train models and learn outputs.![IMG_20250111_183421.png](data:image/png;base64,...)

# %% [markdown]
# *   Unsupervised learning - Uses unlabeled data to learn about patterns in data.
#
# ![IMG_20250111_185605.png](data:image/png;base64,...)

# %% [markdown]
# *  Reinforcement learning - Agent learning in interactive environment based on rewards and penalties
